# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read data

# %%
filename = r"G:\Shared drives\Ryoko and Hilary\SMSigxModel\analysis\1_pre_calibration\results\Mahurangi-2023-11-22-KGE-Flow-GLUEparams\DDS_allresults.csv"
df = pd.read_csv(filename)
print(len(df))
df.head()
# Out:
# 500
#    Unnamed: 0     like1      parbb  parsatdk   parslop  parsmcmax  parwltsmc  \
# 0           0  0.730527  14.207524  0.004433  0.720739   0.571964   0.265636
# 1           1  0.435377   7.633150  0.009307  0.880303   0.666512   0.432869
# 2           2  0.717967  17.576589  0.001216  0.702533   0.879415   0.223241
# 3           3  0.844361  14.495388  0.015915  0.107425   0.496288   0.373619
# 4           4  0.680181   8.165884  0.014813  0.745061   0.859146   0.088766
#
#    parmax_gw_storage    parCgw  parexpon  parK_nash  parrefkdt  \
# 0           0.238164  0.001182  1.712452   0.924018   7.364164
# 1           0.060543  0.001345  6.345262   0.573722   3.757499
# 2           0.197294  0.000219  6.253416   0.206114   6.715635
# 3           0.189115  0.001184  4.295356   0.644434   8.257793
# 4           0.178530  0.000206  3.232145   0.425909   9.254215
#
#    partrigger_z_fact   parK_lf
# 0           0.568913  0.458200
# 1           0.621748  0.648099
# 2           0.636640  0.810599
# 3           0.359472  0.583651
# 4           0.336087  0.896365

# %%
# parameter_names = ["parbb","parsatdk","parslop","parsmcmax","parwltsmc","parmax_gw_storage"]
parameter_names = ["parbb","parsatdk","parslop","parsmcmax","parwltsmc","parmax_gw_storage","parCgw","parexpon","parK_nash","parrefkdt","partrigger_z_fact","parK_lf"] #,"parnum_nash_storage"]
# parameter_names = ["parbb","parsatdk","parsatpsi","parslop","parsmcmax","parwltsmc","parmax_gw_storage","parCgw","parexpon","parK_nash","parrefkdt","partrigger_z_fact","paralpha_fc","parK_lf","parD","parnum_nash_storage"]

# %% [markdown]
# ## Get dotty plots on the parameter values

# %%
num_plots = len(parameter_names)
fig, axes = plt.subplots(4, 4, figsize=(15, 12))  # Adjust figsize as needed
for i, parameter_name in enumerate(parameter_names):
    row, col = divmod(i, 4)
    axes[row, col].scatter(df[parameter_name].values, df["like1"].values, alpha=0.5)
    axes[row, col].set_xlabel(parameter_name)
    axes[row, col].set_ylabel("KGE")
    axes[row, col].set_ylim([-0.41, 1])
fig.tight_layout()

# %% [markdown]
# ## Get the best parameter sets

# %%
import numpy as np
df[df["like1"]==np.nanmax(df["like1"])]
# Out:
#      Unnamed: 0     like1      parbb  parsatdk   parslop  parsmcmax  \
# 499         499  0.948805  11.849242  0.005666  0.043662   0.516242
#
#      parwltsmc  parmax_gw_storage  parCgw  parexpon  parK_nash  parrefkdt  \
# 499   0.296431           0.142888  0.0018  4.477433   0.013168   6.200045
#
#      partrigger_z_fact   parK_lf
# 499            0.39011  0.784221
